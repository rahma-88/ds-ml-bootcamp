# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'car_price_prediction.ipynb', 'clean_car_dataset.csv']

# %%
import pandas as pd

df = pd.read_csv("clean_car_dataset.csv")

print(df.head())

print("\nShape:")
print(df.shape)
# Out:
#     Price  Odometer_km     Doors  Accidents      Year  Location_City  \
# 0  1500.0     0.128390  0.254091   0.316968 -1.686714              1
# 1  4171.0    -0.044709  0.254091  -0.820867  0.794617              0
# 2  5331.0    -0.440923  0.254091  -0.820867  0.518913              0
# 3  1500.0     0.203135  0.254091   0.316968 -1.548862              0
# 4  1500.0    -0.044709 -0.931668  -0.820867  1.621727              1
#
#    Location_Rural  Location_Suburb    CarAge  Km_per_year  Is_Urban  LogPrice
# 0               0                0  1.686714    -0.615631         1  7.313887
# 1               1                0 -0.794617     0.070446         0  8.336151
# 2               0                1 -0.518913    -0.267993         1  8.581482
# 3               0                1  1.548862    -0.587024         1  7.313887
# 4               0                0 -1.621727     1.738196         1  7.313887
#
# Shape:
# (140, 12)

# %%
# !pip install pandas numpy scikit-learn matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv("clean_car_dataset.csv")

print(df.head())
print(df.shape)
# Out:
#     Price  Odometer_km     Doors  Accidents      Year  Location_City  \
# 0  1500.0     0.128390  0.254091   0.316968 -1.686714              1
# 1  4171.0    -0.044709  0.254091  -0.820867  0.794617              0
# 2  5331.0    -0.440923  0.254091  -0.820867  0.518913              0
# 3  1500.0     0.203135  0.254091   0.316968 -1.548862              0
# 4  1500.0    -0.044709 -0.931668  -0.820867  1.621727              1
#
#    Location_Rural  Location_Suburb    CarAge  Km_per_year  Is_Urban  LogPrice
# 0               0                0  1.686714    -0.615631         1  7.313887
# 1               1                0 -0.794617     0.070446         0  8.336151
# 2               0                1 -0.518913    -0.267993         1  8.581482
# 3               0                1  1.548862    -0.587024         1  7.313887
# 4               0                0 -1.621727     1.738196         1  7.313887
# (140, 12)

# %%
X = df.drop(columns=["Price", "LogPrice"])

y = df["Price"]

print("X Shape:", X.shape)
print("y Shape:", y.shape)
# Out:
# X Shape: (140, 10)
# y Shape: (140,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (112, 10)
# Testing Shape: (28, 10)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)

print("Random Forest trained successfully!")
# Out:
# Random Forest trained successfully!

# %%
import numpy as np
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)

def evaluate_model(model, X_test, y_test, name):

    predictions = model.predict(X_test)

    r2 = r2_score(y_test, predictions)
    mae = mean_absolute_error(y_test, predictions)
    mse = mean_squared_error(y_test, predictions)
    rmse = np.sqrt(mse)

    print(f"\n{name} Performance:")
    print(f"R²   : {r2:.4f}")
    print(f"MAE  : {mae:.2f}")
    print(f"MSE  : {mse:.2f}")
    print(f"RMSE : {rmse:.2f}")

# %%
evaluate_model(
    linear_model,
    X_test,
    y_test,
    "Linear Regression"
)

evaluate_model(
    rf_model,
    X_test,
    y_test,
    "Random Forest"
)
# Out:
# Linear Regression Performance:
# R²   : 0.4358
# MAE  : 1428.05
# MSE  : 3755299.23
# RMSE : 1937.86
#
# Random Forest Performance:
# R²   : 0.2430
# MAE  : 1238.45
# MSE  : 5038456.04
# RMSE : 2244.65

# %%
i = 0

sample = X_test.iloc[[i]]

actual_price = y_test.iloc[i]

linear_pred = linear_model.predict(sample)[0]

rf_pred = rf_model.predict(sample)[0]

print("Actual Price:", actual_price)
print("Linear Regression Prediction:", round(linear_pred, 2))
print("Random Forest Prediction:", round(rf_pred, 2))
# Out:
# Actual Price: 4379.0
# Linear Regression Prediction: 5040.46
# Random Forest Prediction: 4598.23

# %%
print(df.corr(numeric_only=True)["Price"].sort_values(ascending=False))
# Out:
# Price              1.000000
# LogPrice           0.980956
# Year               0.505173
# Doors              0.131168
# Km_per_year        0.110286
# Is_Urban           0.068851
# Location_City      0.034537
# Location_Suburb    0.015218
# Location_Rural    -0.068851
# Accidents         -0.119951
# Odometer_km       -0.500709
# CarAge            -0.505173
# Name: Price, dtype: float64
